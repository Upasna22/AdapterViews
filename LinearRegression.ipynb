# %% [markdown]
# <a href="https://colab.research.google.com/github/Upasna22/AdapterViews/blob/master/LinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model

#dataset
diabetes_x, diabetes_y = datasets.load_diabetes(return_X_y=True)

diabetes_x = diabetes_x[:, np.newaxis, 2]

#print(diabetes_x)


#Training aand Test X axis
diabetes_x_train = diabetes_x[:-20]
diabetes_x_test = diabetes_x[-20:]

#Training aand Test Y axis
diabetes_y_train = diabetes_y[:-20]
diabetes_y_test = diabetes_y[-20:]


LinearRegression = linear_model.LinearRegression()

LinearRegression.fit(diabetes_x_train, diabetes_y_train)

LR_Y_Predict = LinearRegression.predict(diabetes_x_test)

print("Linear Regression prediction", LR_Y_Predict)

plt.scatter(diabetes_x_train, diabetes_y_train, color='green')
plt.scatter(diabetes_x_test, diabetes_y_test, color='blue')
# Out:
# Linear Regression prediction [225.9732401  115.74763374 163.27610621 114.73638965 120.80385422
#  158.21988574 236.08568105 121.81509832  99.56772822 123.83758651
#  204.73711411  96.53399594 154.17490936 130.91629517  83.3878227
#  171.36605897 137.99500384 137.99500384 189.56845268  84.3990668 ]

# %%
plt.plot(diabetes_x_test, LR_Y_Predict, color = 'blue')
